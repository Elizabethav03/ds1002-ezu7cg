# %% [markdown]
# <a href="https://colab.research.google.com/github/Elizabethav03/ds1002-ezu7cg/blob/main/Practice_9_22_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# import mockroo
mock_data = pd.read_csv("MOCK_DATA.csv")

# %%
mock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   age         1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %%
mock_data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# get the head rows
mock_data.head(3)
# Out:
#    id first_name   last_name                       email  gender  age
# 0   1    Patrica       Bryan             pbryan0@wsj.com  Female   25
# 1   2     Jessey        Geke             jgeke1@1und1.de    Male   86
# 2   3      Odele  Yepiskopov  oyepiskopov2@woothemes.com  Female   40

# %%
mock_data.tail()
# Out:
#        id first_name last_name                       email  gender  age
# 995   996     Jorrie   Fosdike           jfosdikern@ft.com  Female   83
# 996   997      Emmey    Gencke  egenckero@odnoklassniki.ru  Female   43
# 997   998  Chantalle    Lutton       cluttonrp@nbcnews.com  Female   33
# 998   999     Hebert   Farreil    hfarreilrq@microsoft.com    Male   54
# 999  1000       Anya  Bensusan     abensusanrr@behance.net  Female   52

# %%
# grab specific data
mock_data.loc[9]
# Out:
# id                         10
# first_name            Tirrell
# last_name              Gronav
# email         tgronav9@go.com
# gender                   Male
# age                        46
# Name: 9, dtype: object

# %%
mock_data.describe()
# Out:
#                 id          age
# count  1000.000000  1000.000000
# mean    500.500000    46.570000
# std     288.819436    26.265242
# min       1.000000     1.000000
# 25%     250.750000    24.000000
# 50%     500.500000    46.000000
# 75%     750.250000    71.000000
# max    1000.000000    90.000000

# %%
# get the columns from the df
mock_data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object')

# %%
# what data types of in this df
mock_data.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# age            int64
# dtype: object

# %%
mock_data = mock_data.rename(columns={"first_name":"fname","last_name":"lname"})

# %%
mock_data.head()
# Out:
#    id    fname       lname                         email  gender  age
# 0   1  Patrica       Bryan               pbryan0@wsj.com  Female   25
# 1   2   Jessey        Geke               jgeke1@1und1.de    Male   86
# 2   3    Odele  Yepiskopov    oyepiskopov2@woothemes.com  Female   40
# 3   4    Ranna       Arnao           rarnao3@yahoo.co.jp  Female   59
# 4   5    Nelie     Arnoldi  narnoldi4@chicagotribune.com  Female   84

# %%
mock_data['fname']
# Out:
# 0        Patrica
# 1         Jessey
# 2          Odele
# 3          Ranna
# 4          Nelie
#          ...
# 995       Jorrie
# 996        Emmey
# 997    Chantalle
# 998       Hebert
# 999         Anya
# Name: fname, Length: 1000, dtype: object

# %%
mock_data.fname
# Out:
# 0        Patrica
# 1         Jessey
# 2          Odele
# 3          Ranna
# 4          Nelie
#          ...
# 995       Jorrie
# 996        Emmey
# 997    Chantalle
# 998       Hebert
# 999         Anya
# Name: fname, Length: 1000, dtype: object

# %%
mock_data[['fname','lname']]
# Out:
#          fname       lname
# 0      Patrica       Bryan
# 1       Jessey        Geke
# 2        Odele  Yepiskopov
# 3        Ranna       Arnao
# 4        Nelie     Arnoldi
# ..         ...         ...
# 995     Jorrie     Fosdike
# 996      Emmey      Gencke
# 997  Chantalle      Lutton
# 998     Hebert     Farreil
# 999       Anya    Bensusan
#
# [1000 rows x 2 columns]

# %%
pd.value_counts(mock_data['gender']).plot.bar()
# Out:
# <Axes: >

# %%
mock_data.groupby(['gender'])['age'].mean()
# Out:
# gender
# Agender        50.333333
# Bigender       37.631579
# Female         46.884701
# Genderfluid    37.571429
# Genderqueer    35.000000
# Male           47.109865
# Non-binary     44.117647
# Polygender     49.083333
# Name: age, dtype: float64
